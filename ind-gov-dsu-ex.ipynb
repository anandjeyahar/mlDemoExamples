# %%
import bokeh
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="26793d35-d804-427a-b72b-53ab539ac82d">Loading BokehJS ...</span>
#     </div>

# %%
## Get some data
import pandas as pd
#cashReserve18Nov2016 = pd.read_excel('https://rbidocs.rbi.org.in/rdocs/content/docs/PR130423112016_RM.xls')
cashReserve18Nov2016 = pd.read_excel('/home/anand/DataScientist/data/PR130423112016_RM.xls')

# %%
cashReserve18Nov2016.head()
# Out:
#    Unnamed: 0 Statement on Reserve Money            Unnamed: 2  \
# 0         NaN                 (` billion)                  NaN
# 1         NaN                        ITEM                  NaN
# 2         NaN                         NaN                2016#
# 3         NaN                         NaN                  NaN
# 4         NaN                         NaN  2016-03-31 00:00:00
#
#             Unnamed: 3       Unnamed: 4 Unnamed: 5             Unnamed: 6  \
# 0                  NaN              NaN        NaN                    NaN
# 1                  NaN  Variations over        NaN                    NaN
# 2               2016 #             Week        NaN  Financial Year so far
# 3                  NaN              NaN        NaN                2015-16
# 4  2016-11-18 00:00:00           Amount          %                 Amount
#
#   Unnamed: 7           Unnamed: 8 Unnamed: 9   Unnamed: 10 Unnamed: 11  \
# ...

# %%
import datascienceutils as dsu
from datascienceutils import analyze
cashReserve18Nov2016.fillna(0, inplace=True)

analyze.correlation_analyze(cashReserve18Nov2016,'Unnamed: 5', 'Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-fb3da2322859> in <module>()
#       3 cashReserve18Nov2016.fillna(0, inplace=True)
#       4
# ----> 5 analyze.correlation_analyze(cashReserve18Nov2016,'Unnamed: 5', 'Unnamed: 0')
#
# /home/anand/anaconda3/envs/analytics/lib/python3.5/site-packages/datascienceutils-1.2.19-py3.5.egg/datascienceutils/analyze.py in correlation_analyze(df, col1, col2, categories, measures, summary_only, check_linearity, trellis)
#     135     u,v = col1, col2
#     136     plots.append(plotter.scatterplot(df, u, v))
# --> 137     plots.append(plotter.sb_jointplot(df[u], df[v]))
#     138     if check_linearity:
#     139         u_2diff = np.gradient(df[u], 2)
#
# /home/anand/anaconda3/envs/analytics/lib/python3.5/site-packages/datascienceutils-1.2.19-py3.5.egg/datascienceutils/plotter.py in sb_jointplot(series1, series2)
#     535
# ...

# %%
cashReserve18Nov2016['Unnamed: 0']
