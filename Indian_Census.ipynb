# %%
import pandas as pd
import os

# %%
census_2011_tn = os.path.expanduser('~/DataScientist/data/CensusIndia/2011/TNcsvs')
census_2001 = os.path.expanduser('~/DataScientist/data/CensusIndia/2001')

# %%
census_2001_district_wise_df = pd.read_csv(os.path.join(census_2001, 'all.csv'))

# %%
census_2001_district_wise_df.head()
# Out:
#    Unnamed: 0   State                                           District  \
# 0           1      AN  District Andamans (01), Andaman & Nicobar Isla...
# 1           2      AN  District Nicobars (02), Andaman & Nicobar Isla...
# 2           3  Andhra        District Adilabad (01), Andhra Pradesh (28)
# 3           4  Andhra       District Nizamabad (02), Andhra Pradesh (28)
# 4           5  Andhra      District Karimnagar (03), Andhra Pradesh (28)
#
#    Persons    Males  Females Growth..1991...2001.    Rural   Urban  \
# 0   314084   170319   143765                30.14   197886  116198
# 1    42068    22653    19415                 7.19    42068       -
# 2  2488003  1250958  1237045                19.06  1827986     NaN
# 3  2345685  1162905  1182780                14.98  1920947     NaN
# 4  3491822  1747968  1743854                14.47  2813010     NaN
#
#   Scheduled.Caste.population       ...        Medical.facility  \
# ...

# %%
census_2001_district_wise_df.District.unique()
# Out:
# array(['District Andamans (01), Andaman & Nicobar Islands (35)',
#        'District Nicobars (02), Andaman & Nicobar Islands (35)',
#        'District Adilabad (01), Andhra Pradesh (28)',
#        'District Nizamabad (02), Andhra Pradesh (28)',
#        'District Karimnagar (03), Andhra Pradesh (28)',
#        'District Medak (04), Andhra Pradesh (28)',
#        'District Hyderabad (05), Andhra Pradesh (28)',
#        'District Rangareddi (06), Andhra Pradesh (28)',
#        'District Mahbubnagar (07), Andhra Pradesh (28)',
#        'District Nalgonda (08), Andhra Pradesh (28)',
#        'District Warangal (09), Andhra Pradesh (28)',
#        'District Khammam (10), Andhra Pradesh (28)',
#        'District Srikakulam (11), Andhra Pradesh (28)',
#        'District Vizianagaram (12), Andhra Pradesh (28)',
#        'District Visakhapatnam (13), Andhra Pradesh (28)',
#        'District West Godavari (15), Andhra Pradesh (28)',
#        'District Krishna (16), Andhra Pradesh (28)',
# ...

# %%
census_2001_dindigul_df = census_2001_district_wise_df[census_2001_district_wise_df.District=='District Dindigul (13), Tamil Nadu (33)'].copy(deep=True)
census_2001_dindigul_df.head()
# Out:
#      Unnamed: 0 State                                 District  Persons  \
# 467         468    TN  District Dindigul (13), Tamil Nadu (33)  1923014
#
#       Males  Females Growth..1991...2001.    Rural Urban  \
# 467  968137   954877                 8.99  1249762   NaN
#
#     Scheduled.Caste.population       ...        Medical.facility  \
# 467                        NaN       ...                     283
#
#      Primary.Health.Centre  Primary.Health.Sub.Centre  \
# 467                     60                        210
#
#      Post..telegraph.and.telephone.facility  Bus.services Paved.approach.road  \
# 467                                   299.0           305                 312
#
#     Mud.approach.road  Permanent.House  Semi.permanent.House  Temporary.House
# 467               266             58.6                  24.1             17.3
#
# [1 rows x 82 columns]

# %%
census_2011_dindigul_df = pd.read_csv(os.path.join(census_2011_tn, 'PCA_CDB_3311_F_Census_Dindigul.csv'))

# %%
census_2011_dindigul_df.head()
# Out:
#    State/UTs_Code  District_Code  CD Block_Code  Town/Village_Code  Ward_Code  \
# 0              33            612            141                  0          0
# 1              33            612            141                  0          0
# 2              33            612            141                  0          0
# 3              33            612            141             635353          0
# 4              33            612            141             635354          0
#
#    EB_Code State/UTs_Name District_Name     Level              Name  \
# 0        0     TAMIL NADU      Dindigul  CD BLOCK          Dindigul
# 1        0     TAMIL NADU      Dindigul  CD BLOCK          Dindigul
# 2        0     TAMIL NADU      Dindigul  CD BLOCK          Dindigul
# 3        0     TAMIL NADU      Dindigul   VILLAGE         Mullipadi
# 4        0     TAMIL NADU      Dindigul   VILLAGE  Ammakulathupatti
#
#                ...                \
# 0              ...
# 1              ...
# ...

# %%
census_2011_dindigul_df['Non Working Population Person'].sum()
# Out:
# 1951173

# %%
census_2011_dindigul_df.groupby('Level').count()
# Out:
#           State/UTs_Code  District_Code  CD Block_Code  Town/Village_Code  \
# Level
# CD BLOCK              45             45             45                 45
# TOWN                   7              7              7                  7
# VILLAGE              362            362            362                362
#
#           Ward_Code  EB_Code  State/UTs_Name  District_Name  Name  \
# Level
# CD BLOCK         45       45              45             45    45
# TOWN              7        7               7              7     7
# VILLAGE         362      362             362            362   362
#
#           Total/Rural/Urban              ...                \
# Level                                    ...
# CD BLOCK                 45              ...
# TOWN                      7              ...
# VILLAGE                 362              ...
#
#           Marginal Agriculture Labourers Population 0_3 Female  \
# Level
# CD BLOCK                                                 45
# ...
